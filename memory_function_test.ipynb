# %%
import numpy as np
import matplotlib.pyplot as plt

import torch

from src.memoryfunction import memoryfunction

# %%
D = 16

model = torch.nn.RNN(D, D, 1, batch_first=True)
# model = torch.nn.GRU(D, D, 1, batch_first=True)
# model = torch.nn.LSTM(D, D, 1, batch_first=True)

mf = memoryfunction(model, D=D)
print(mf)
# Out:
# [0.8777203  0.34851804 0.10542883 ... 0.         0.         0.        ]

# %%
plt.figure(figsize=(10, 6))
plt.plot(mf)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Time")
plt.ylabel("Memory function")
plt.title("Memory function")
plt.show()
